# %% [markdown]
# # Importing Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Creating path

path = r'C:\Users\stefa\15-02-2022 Instacart Basket Analysis'

# %%
# In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
# Importing orders_products_combined.pkl

df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Check the shape of the imported dataframe

# %%
df_orders_products_combined.shape
# Out:
# (32640698, 13)

# %%
df_orders_products_combined.describe()
# Out:
#          Unnamed: 0  Unnamed: 0.1      order_id       user_id  order_number  \
# count  3.264070e+07  3.264070e+07  3.264070e+07  3.264070e+07  3.264070e+07
# mean   1.709876e+06  1.709876e+06  1.710719e+06  1.029383e+05  1.713856e+01
# std    9.864701e+05  9.864701e+05  9.873085e+05  5.946686e+04  1.752967e+01
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.556322e+05  8.556322e+05  8.558860e+05  5.142200e+04  5.000000e+00
# 50%    1.709181e+06  1.709181e+06  1.710984e+06  1.026160e+05  1.100000e+01
# 75%    2.565971e+06  2.565971e+06  2.565490e+06  1.543940e+05  2.400000e+01
# max    3.421082e+06  3.421082e+06  3.421083e+06  2.062090e+05  1.000000e+02
#
#        orders_day_of_week    order_time  days_since_prior_order    product_id  \
# count        3.264070e+07  3.264070e+07            3.056263e+07  3.243449e+07
# mean         2.739040e+00  1.342599e+01            1.114427e+01  2.557634e+04
# ...

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 0           0             0   2539329        1             1
# 1           0             0   2539329        1             1
# 2           0             0   2539329        1             1
# 3           0             0   2539329        1             1
# 4           0             0   2539329        1             1
#
#    orders_day_of_week  order_time  days_since_prior_order  First_order  \
# 0                   2           8                     NaN         True
# 1                   2           8                     NaN         True
# 2                   2           8                     NaN         True
# 3                   2           8                     NaN         True
# 4                   2           8                     NaN         True
#
#    product_id  add_to_cart_order  reordered _merge
# 0       196.0                1.0        0.0   both
# 1     14084.0                2.0        0.0   both
# ...

# %%
# Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using

# %%
df_products = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_cleaned.csv'), index_col = False)

# %%
df_products.shape
# Out:
# (49672, 6)

# %%
df_products.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Removal of unwanted Columns for further Use

# %%
df_orders_products_combined_1 = df_orders_products_combined.drop(columns = ['_merge','Unnamed: 0','Unnamed: 0.1'])

# %%
df_products = df_products.drop(columns = ['Unnamed: 0',])

# %%
# Merge DataFrames    / It took me a while to figure out that the first merge caused problems / ValueError: Cannot use name of an existing column for indicator column This was resolved after looking in google for solutions and create a subset and remove the columns

# %%
orders_products_merged = df_orders_products_combined_1.merge(df_products, on = ['product_id'], how = 'left',indicator = True)

# %%
# Confirm the results of the merge using the merge flag.

# %%
orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_time  \
# 0   2539329        1             1                   2           8
# 1   2539329        1             1                   2           8
# 2   2539329        1             1                   2           8
# 3   2539329        1             1                   2           8
# 4   2539329        1             1                   2           8
#
#    days_since_prior_order  First_order  product_id  add_to_cart_order  \
# 0                     NaN         True       196.0                1.0
# 1                     NaN         True     14084.0                2.0
# 2                     NaN         True     12427.0                3.0
# 3                     NaN         True     26088.0                4.0
# 4                     NaN         True     26405.0                5.0
#
#    reordered                             product_name  aisle_id  \
# 0        0.0                                     Soda      77.0
# ...

# %%
orders_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only       236409
# right_only           0
# Name: _merge, dtype: int64

# %%
# Export the newly created dataframe as orders_products_merged in a suitable format

# %%
orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_mergedV2.pkl'))
